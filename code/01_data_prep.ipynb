# %% [markdown]
# #  Data Preparation
# The Adult dataset contains demographic and employment information used to predict whether an individual's annual income exceeds $50,000. During the data preparation phase, missing values represented by the character "?" were identified in the columns workclass, occupation, and native_country. These records were removed using listwise deletion because the proportion of missing observations was relatively small compared with the overall dataset size.
#
# Additional preprocessing steps included removing duplicate records. The cleaned dataset retained more than 30,000 observations, providing a sufficiently large sample for model development and evaluation. These steps improved data quality while maintaining a transparent and reproducible preprocessing workflow.
#
#
# | Cleaning Step                 |              Rows Remaining |
# | ----------------------------- | --------------------------: |
# | Original Dataset              |                      32,561 |
# | Rows with Missing Values      |                       2,399 |
# | After Removing Missing Values |                      30,162 |
# | Duplicate Rows Removed        |      *(your actual number)* |
# | Final Dataset                 | *(your actual final count)* |

# %% [markdown]
# #  Load the data

# %%
import pandas as pd
import numpy as np

columns = [
    "age", "workclass", "fnlwgt", "education", "education_num",
    "marital_status", "occupation", "relationship", "race", "sex",
    "capital_gain", "capital_loss", "hours_per_week",
    "native_country", "income"
]

df = pd.read_csv(
    "data/adult.data",
    header=None,
    names=columns,
    skipinitialspace=True,
    na_values="?"
)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 11
#       7     "capital_gain", "capital_loss", "hours_per_week",
#       8     "native_country", "income"
#       9 ]
#      10
# ---> 11 df = pd.read_csv(
#      12     "adult.data",
#      13     header=None,
#      14     names=columns,
#
# File ~/git/github/AAI-500-Final-Team-Project/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/git/github/AAI-500-Final-Team-Project/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/git/github/AAI-500-Final-Team-Project/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File ~/git/github/AAI-500-Final-Team-Project/.venv/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File ~/git/github/AAI-500-Final-Team-Project/.venv/lib/python3.14/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'adult.data'

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  str
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  str
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  str
#  6   occupation      30718 non-null  str
#  7   relationship    32561 non-null  str
#  8   race            32561 non-null  str
#  9   sex             32561 non-null  str
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  31978 non-null  str
#  14  income          32561 non-null  str
# dtypes: int64(6), str(9)
# memory usage: 3.7 MB

# %% [markdown]
# # Report missing value

# %%
missing = df.isnull().sum()

print("missing values by column")
print(missing[missing > 0])

rows_with_missing = df.isna().any(axis=1).sum()

print(f"rows containing at least one missing value: {rows_with_missing:,}")
# Out:
# missing values by column
# workclass         1836
# occupation        1843
# native_country     583
# dtype: int64
# rows containing at least one missing value: 2,399

# %% [markdown]
# # Remove rows with missing values
# # Easy to explain the data
# # The data is reproducible
# # No assumptions introduced
# # Still leaves over 30,000 observations

# %%
before_rows = len(df)

print(f"# rows before cleaning: {before_rows:,}")

df_clean = df.dropna(ignore_index=True)

print(f"# rows after cleaning: {len(df_clean)}")
# Out:
# # rows before cleaning: 32,561
# # rows after cleaning: 30162

# %% [markdown]
# # Remove duplicates

# %%
duplicates = df_clean.duplicated().sum()
print(f"# duplicate rows: {duplicates}")
df_clean = df_clean.drop_duplicates()
print(f"rows after cleaning: {len(df_clean)}")
# Out:
# # duplicate rows: 23
# rows after cleaning: 30139

# %% [markdown]
# # Final Dataset

# %%
print("\nfinal dataset summary")
print(f"original rows: {len(df)}")
print(f"rows removed for missing values: {rows_with_missing:,}")
print(f"duplicate rows removed: {duplicates:,}")
print(f"final rows: {len(df_clean):,}")
# Out:
# final dataset summary
# original rows: 32561
# rows removed for missing values: 2,399
# duplicate rows removed: 23
# final rows: 30,139

# %% [markdown]
# # Verify target distribution

# %%
print(df_clean["income"].value_counts())
# Out:
# income
# <=50K    22633
# >50K      7506
# Name: count, dtype: int64
