# %% [markdown]
# ## Placeholder

# %%
import numpy as np
import pandas as pd

print(np.sqrt(4))
print(pd.DataFrame({"A": [1, 2, 3], "B": [4, 5, 6]}))
# Out:
# 2.0
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6
